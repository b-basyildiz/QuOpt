# %% [markdown]
# # Testing

# %% [markdown]
# AUTHOR: Bora Basyildiz

# %% [markdown]
# ## Imports

# %%
from helperFuncs import *

# %%
l = 2
G = zeros((l ** 2, l ** 2),dtype=complex)    
for i in range(l):
    for j in range(l):
        G[i * l + j, j * l + i] = 1
printMat(G)
# Out:
#  1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i,

# %%
l = 3

printMat(G)
# Out:
#  1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,-1.00+0.00i,

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ---- FONT SETTINGS TO MATCH COMPUTER MODERN STYLE ----
plt.rcParams.update({
    "font.family": "serif",
    "mathtext.fontset": "cm",
})

csv_path = "./Revision_Data/capacitiveCoup/Fidelities/qutrit_SWAP_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv"

df = pd.read_csv(
    csv_path,
    header=None,
    names=["F", "T_over_Tmin"]
)

# keep max fidelity for duplicate time points
df = (
    df.groupby("T_over_Tmin", as_index=False)["F"]
    .max()
    .sort_values("T_over_Tmin")
)

plt.figure(figsize=(8, 5), dpi=200)

plt.plot(
    df["T_over_Tmin"],
    df["F"],
    marker="o",
    linewidth=2.5,
    markersize=6,
)

plt.xlabel(r"$T/T_{min}$", fontsize=28)
plt.ylabel(r"$F$", fontsize=32)

plt.grid(True, alpha=0.8)

plt.ylim(0.4, 1.03)

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ---- FIX LATEX ERROR ----
plt.rcParams["text.usetex"] = False

# ---- MATCH FONT STYLE ----
plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "mathtext.fontset": "cm",
})

csv_path = "./Revision_Data/capacitiveCoupUnit/Fidelities/qutrit_CZ_capacitiveCoupUnit_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv"

df = pd.read_csv(
    csv_path,
    header=None,
    names=["F", "T_over_Tmin"]
)

# Keep maximum fidelity for duplicate time points
df = (
    df.groupby("T_over_Tmin", as_index=False)["F"]
    .max()
    .sort_values("T_over_Tmin")
)

plt.plot(
    df["T_over_Tmin"],
    df["F"],
    marker="o"
)

plt.xlabel(r"$T/T_{min}$", fontsize=16)
plt.ylabel(r"$F$", fontsize=16)

plt.grid(True)

plt.tight_layout()
plt.savefig("./Revision_Plots/Unit_CZ.pdf")
plt.show()

# %%
from helperFuncs import *
printMat(genCouplMat("capactiveCoupExtra",3))
# Out:
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i,
#  1.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 4.00+0.00i,
#  0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 4.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 4.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 4.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,

# %%
printMat(genCouplMat("capacitiveCoupUnit",3))
# Out:
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i,
#  1.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 1.00+0.00i,
#  0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_fidelity(
    csv_path: str,
    graph_type: str = "CNOT",
    label: str | None = None,
    ax: plt.Axes | None = None,
    save_path: str | None = None,
) -> plt.Axes:
    plt.rcParams["text.usetex"] = False
    plt.rcParams.update({
        "font.family": "DejaVu Sans",
        "mathtext.fontset": "cm",
    })
    df = pd.read_csv(csv_path, header=None, names=["F", "T_over_Tmin"])
    df = (
        df.groupby("T_over_Tmin", as_index=False)["F"]
        .max()
        .sort_values("T_over_Tmin")
    )
    if ax is None:
        ax = plt.gca()
    ax.plot(df["T_over_Tmin"], df["F"], marker="o", label=label)
    ax.set_xlabel(r"$T/T_{min}^{ %s}$" % graph_type, fontsize=16)
    ax.set_ylabel(r"$F$", fontsize=16)
    ax.grid(True)
    handles, labels = ax.get_legend_handles_labels()
    if labels:
        ax.legend(fontsize=13)
    if save_path:
        ax.get_figure().tight_layout()
        ax.get_figure().savefig(save_path)
    return ax

# %%
fig, ax = plt.subplots()
plot_fidelity("./coupling_data/capacitiveCoup/Fidelities/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="capacitive coup", graph_type="CZ", ax=ax)
plot_fidelity("./coupling_data/capacitiveCoupUnit/Fidelities/qutrit_CZ_capacitiveCoupUnit_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="unit coup", graph_type="CZ", ax=ax)
plot_fidelity("./coupling_data/capacitiveCoupExtra/Fidelities/qutrit_CZ_capacitiveCoupExtra_M40_SGD_CFME4_g1.0_maxT2.0_maxD40_it5000.csv", label="increased coup", graph_type="CZ", ax=ax)
plot_fidelity("./coupling_data/capacitiveCoupMin/Fidelities/qutrit_CZ_capacitiveCoupMin_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="minimized coup", graph_type="CZ", ax=ax)
plt.tight_layout()
plt.savefig('./Revision_Plots/CZ_Couplings.pdf')
plt.show()

# %% [markdown]
# ## Final Paper Revisions
#
# CZ coupling comparison (capacitive / unit / increased / minimized) regenerated using `Fixed_New_Data`.

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_fidelity(
    csv_path: str,
    graph_type: str = "CNOT",
    label: str | None = None,
    ax: plt.Axes | None = None,
    save_path: str | None = None,
) -> plt.Axes:
    plt.rcParams["text.usetex"] = False
    plt.rcParams.update({
        "font.family": "DejaVu Sans",
        "mathtext.fontset": "cm",
    })
    df = pd.read_csv(csv_path, header=None, names=["F", "T_over_Tmin"])
    df = (
        df.groupby("T_over_Tmin", as_index=False)["F"]
        .max()
        .sort_values("T_over_Tmin")
    )
    if ax is None:
        ax = plt.gca()
    ax.plot(df["T_over_Tmin"], df["F"], marker="o", label=label)
    ax.set_xlabel(r"$T/T_{min}^{ %s}$" % graph_type, fontsize=16)
    ax.set_ylabel(r"$F$", fontsize=16)
    ax.grid(True)
    handles, labels = ax.get_legend_handles_labels()
    if labels:
        ax.legend(fontsize=13)
    if save_path:
        ax.get_figure().tight_layout()
        ax.get_figure().savefig(save_path)
    return ax

# %%
from helperFuncs import *
fig, ax = plt.subplots()
plot_fidelity("./Fixed_New_Data/Closed_System/capacitiveCoup/Fidelities/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="capacitive coup", graph_type="CZ", ax=ax)
plot_fidelity("./Fixed_New_Data/Closed_System/capacitiveCoupUnit/Fidelities/qutrit_CZ_capacitiveCoupUnit_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="unit coup", graph_type="CZ", ax=ax)
plot_fidelity("./Fixed_New_Data/Closed_System/capacitiveCoupExtra/Fidelities/qutrit_CZ_capacitiveCoupExtra_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="increased coup", graph_type="CZ", ax=ax)
plot_fidelity("./Fixed_New_Data/Closed_System/capacitiveCoupMin/Fidelities/qutrit_CZ_capacitiveCoupMin_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="minimized coup", graph_type="CZ", ax=ax)
plt.tight_layout()
#plt.savefig('./Revision_Plots/CZ_Couplings_Fixed.pdf')
plt.show()

# %%
fig, ax = plt.subplots()
plot_fidelity("./Fixed_New_Data/Closed_System/capacitiveCoupUnit/Fidelities/qutrit_CZ_capacitiveCoupUnit_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="QuOpt", graph_type="CZ", ax=ax)
plot_fidelity("./Fixed_New_Data/Closed_System/Sahel_Data/QutritSpeedLimits_QutritCZ_3_5_0_ENC.csv", label="GRAPE", graph_type="CZ", ax=ax)
plt.savefig('./Revision_Plots/CZ_Excitation_Conserv.pdf')
plt.show()

# %%
plot_fidelity(
    "./coupling_data/capacitiveCoup/Fidelities/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv",
    graph_type="CZ"
)
plt.tight_layout()
plt.show()

# %%
#SWAP Data
fig, ax = plt.subplots()
plot_fidelity("./Revision_Data/capacitiveCoup/Fidelities/qutrit_SWAP_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="QuOpt", graph_type="SWAP", ax=ax)
plot_fidelity("./Revision_Data/Sahel_Data/QuditSWAPFidelity_3_FullOnePhotonControl.csv", label="GRAPE", graph_type="SWAP", ax=ax)
plt.tight_layout()
#plt.savefig('./Revision_Plots/SWAP_Comparison.pdf')
plt.show()

# %%
#TOFFOLI Data
fig, ax = plt.subplots()
plot_fidelity("./Revision_Data/capacitiveCoup/Fidelities/qutrit_Toffoli_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="QuOpt", graph_type="Toffoli", ax=ax)
plot_fidelity("./Revision_Data/Sahel_Data/QutritSpeedLimits_QutritTLG_3_5_0_2.csv", label="GRAPE", graph_type="Toffoli", ax=ax)
plt.tight_layout()
#plt.savefig('./Revision_Plots/Toffoli_Comparison.pdf')
plt.show()

# %%
OLI")

ax = plt.gca()
ax.legend(fontsize=13)
plt.tight_layout()
#plt.savefig("./Revision_Plots/Toffoli_Comparison.pdf")
plt.show()

# %%
printMat(genCouplMat("capacitiveCoup",3))
# Out:
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i,
#  1.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 2.00+0.00i,
#  0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,

# %%
def capacitiveCoup_EC(level):
    """
    Excitation-conserving part of the capacitive coupling:
    H = kron(a†, a) + kron(a, a†)
    Keeps only terms where one qudit loses an excitation and the other gains one.
    Equivalent to 'AshhabHopp' in genCouplMat.
    """
    a = np.zeros((level, level))
    for i in range(level - 1):
        a[i, i+1] = np.sqrt(i + 1)   # annihilation operator
    adag = a.T                         # creation operator
    return kron(adag, a) + kron(a, adag)

H0_EC = capacitiveCoup_EC(3)
printMat(H0_EC)
# Out:
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,

# %%
# Reconstruct the qutrit CZ unitary from weights and compute fidelity.
weights_path = "./coupling_data/capacitiveCoup/Weights/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv"
weights = pd.read_csv(weights_path, header=None).to_numpy()
print("Loaded weights:", weights.shape, "from", weights_path)

level = 3
N = 2
M = weights.shape[0]
maxDriveStrength = 40
t_ratio = 1.0
tmin = np.pi / 4
gate_time = t_ratio * tmin

H0 = torch.tensor(genCouplMat("capacitiveCoup", level), dtype=torch.cdouble)

id_level = np.eye(level)
drives = []
for l in range(1, level):
    drives.append(genDrive(level, l, "x"))
    drives.append(genDrive(level, l, "y"))


def sum_pauli(coef, gate, t):
    total_pauli = torch.zeros((level ** N, level ** N), dtype=torch.cdouble)
    for i in range(N):
        pauli_temp = 1
        for j in range(i):
            pauli_temp = np.kron(pauli_temp, id_level)
        pauli_temp = np.kron(pauli_temp, gate)
        for j in range(i + 1, N):
            pauli_temp = np.kron(pauli_temp, id_level)
        shape = (np.sin(np.pi * t * M / tmin)) ** 2
        total_pauli = total_pauli + shape * maxDriveStrength * torch.cos(coef[i]) * torch.tensor(pauli_temp, dtype=torch.cdouble)
    return total_pauli


def H_segment(t, m):
    pc = torch.tensor(weights[m], dtype=torch.double)
    H1 = torch.zeros((level ** N, level ** N), dtype=torch.cdouble)
    for i, d in enumerate(drives):
        H1 = H1 + sum_pauli(pc[i * N:(i + 1) * N], d, t)
    return H0 + H1

U = torch.eye(level ** N, dtype=torch.cdouble)
for m in range(M):
    U = SRK2(m / M * gate_time, (m + 1) / M * gate_time, U, 0.001, lambda t: H_segment(t, m))

input_gate = torch.tensor(gateGen("CZ", level), dtype=torch.cdouble)

SU = genTwoQuditBasis(level, level, torch.cdouble)

fid = 0
for U_basis in SU:
    eps_U = torch.matmul(torch.matmul(U, U_basis), U.conj().T)
    target_U = torch.matmul(torch.matmul(input_gate, U_basis.conj().T), input_gate.conj().T)
    fid = fid + torch.trace(torch.matmul(target_U, eps_U))

d2 = level ** N
fidelity = abs((fid + d2 ** 2) / ((d2 ** 2) * (d2 + 1)))
print(f"Reconstructed qutrit CZ fidelity = {fidelity:.10f}")
# Out:
# Loaded weights: (40, 8) from ./coupling_data/capacitiveCoup/Weights/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv
# Reconstructed qutrit CZ fidelity = 0.1158802774

# %%
import glob

weight_files = glob.glob("**/Weights_t1.0.csv", recursive=True)
print('Found weight files:', len(weight_files))

results = []
for path in weight_files:
    if 'qutrit_CZ_capacitiveCoup' not in path:
        continue
    try:
        weights = pd.read_csv(path, header=None).to_numpy()
        M = weights.shape[0]
        U = torch.eye(level ** N, dtype=torch.cdouble)
        for m in range(M):
            pulse_coef = torch.tensor(weights[m], dtype=torch.double)
            H1 = torch.zeros((level ** N, level ** N), dtype=torch.cdouble)
            for i, d in enumerate(drives):
                H1 = H1 + sum_pauli(pulse_coef[i * N:(i + 1) * N], d)
            H = H0 + H1
            U = torch.matmul(torch.matrix_exp(-1j * H * (gate_time / M)), U)
        SU = genTwoQuditBasis(level, level, torch.cdouble)
        fid = 0
        for U_basis in SU:
            eps_U = torch.matmul(torch.matmul(U, U_basis), U.conj().T)
            target_U = torch.matmul(torch.matmul(input_gate, U_basis.conj().T), input_gate.conj().T)
            fid += torch.trace(torch.matmul(target_U, eps_U))
        fidelity = abs((fid + d2 ** 2) / ((d2 ** 2) * (d2 + 1)))
        results.append((path, fidelity.item()))
    except Exception as e:
        print('error', path, e)

for path, fid in sorted(results, key=lambda x: x[1], reverse=True):
    print(f'{fid:.10f}    {path}')
# Out:
# Found weight files: 15
# 0.9741365022    coupling_data/capacitiveCoupMin/Weights/qutrit_CZ_capacitiveCoupMin_M40_SGD_CFME4_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv
# 0.9533628090    coupling_data/capacitiveCoupUnit/Weights/qutrit_CZ_capacitiveCoupUnit_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv
# 0.9533628090    Revision_Data/capacitiveCoupUnit/Weights/qutrit_CZ_capacitiveCoupUnit_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv
# 0.9281358889    coupling_data/capacitiveCoupExtra/Weights/qutrit_CZ_capacitiveCoupExtra_M40_SGD_CFME4_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv
# 0.3375600790    coupling_data/capacitiveCoup/Weights/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv
# 0.3375600790    Revision_Data/capacitiveCoup/Weights/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv
# ...

# %%
# Reconstruct fidelity for the two qutrit CZ capacitiveCoup weight files in QutritSpeedLimitData.
check_paths = [
    "../QutritSpeedLimitData/Weights/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv",
    "../QutritSpeedLimitData/Weights/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT1.2_maxD40_it5000_Weights/Weights_t1.0.csv",
]
for weights_path in check_paths:
    try:
        weights = pd.read_csv(weights_path, header=None).to_numpy()
        M = weights.shape[0]
        U = torch.eye(level ** N, dtype=torch.cdouble)
        for m in range(M):
            pulse_coef = torch.tensor(weights[m], dtype=torch.double)
            H1 = torch.zeros((level ** N, level ** N), dtype=torch.cdouble)
            for i, d in enumerate(drives):
                H1 = H1 + sum_pauli(pulse_coef[i * N:(i + 1) * N], d)
            H = H0 + H1
            U = torch.matmul(torch.matrix_exp(-1j * H * (gate_time / M)), U)
        SU = genTwoQuditBasis(level, level, torch.cdouble)
        fid = 0
        for U_basis in SU:
            eps_U = torch.matmul(torch.matmul(U, U_basis), U.conj().T)
            target_U = torch.matmul(torch.matmul(input_gate, U_basis.conj().T), input_gate.conj().T)
            fid += torch.trace(torch.matmul(target_U, eps_U))
        fidelity = abs((fid + d2 ** 2) / ((d2 ** 2) * (d2 + 1)))
        print(weights_path, fidelity.item())
    except Exception as e:
        print('error', weights_path, e)
# Out:
# ../QutritSpeedLimitData/Weights/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000_Weights/Weights_t1.0.csv 0.33756007896345464
# ../QutritSpeedLimitData/Weights/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT1.2_maxD40_it5000_Weights/Weights_t1.0.csv 0.3117484892873981

# %%
# Check the published fidelity for t=1.0 in the CSV file.
cz_fidelities = pd.read_csv(
    "../QutritSpeedLimitData/Fidelities/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv",
    header=None,
).to_numpy()
rows = cz_fidelities[np.isclose(cz_fidelities[:, 1], 1.0)]
print('CSV rows at t=1.0:', rows)
print('max fidelity in CSV:', np.max(cz_fidelities[:, 0]))
print('min fidelity in CSV:', np.min(cz_fidelities[:, 0]))
# Out:
# CSV rows at t=1.0: [[0.98782847 1.        ]
#  [0.98372658 1.        ]
#  [0.97669002 1.        ]
#  [0.98052539 1.        ]
#  [0.98848216 1.        ]
#  [0.98688833 1.        ]
#  [0.98831492 1.        ]
#  [0.97836056 1.        ]
#  [0.98986129 1.        ]
#  [0.9796853  1.        ]
#  [0.98020232 1.        ]
#  [0.9716254  1.        ]
#  [0.97675988 1.        ]
#  [0.99001103 1.        ]
#  [0.97905713 1.        ]
#  [0.97974312 1.        ]
#  [0.98342707 1.        ]
#  [0.97541639 1.        ]
#  [0.99802158 1.        ]
#  [0.99332199 1.        ]
#  [0.97504874 1.        ]
#  [0.98592527 1.        ]
#  [0.97873952 1.        ]
#  [0.98780684 1.        ]
#  [0.9921612  1.        ]
#  [0.99122697 1.        ]
#  [0.98360762 1.        ]
#  [0.98605007 1.        ]
#  [0.98857643 1.        ]
#  [0.99091449 1.        ]
#  [0.9863108  1.        ]
#  [0.98018575 1.        ]
#  [0.98182663 1.        ]
#  [0.99058079 1.        ]
#  [0.98230699 1.        ]
#  [0.98628645 1.        ]
# ...

# %%
# Check the published fidelity for t=1.0 in the CSV file.
cz_fidelities = pd.read_csv(
    "../QutritSpeedLimitData/Fidelities/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv",
    header=None,
).to_numpy()
rows = cz_fidelities[np.isclose(cz_fidelities[:, 1], 1.0)]
print('CSV rows at t=1.0:', rows)
print('max fidelity in CSV:', np.max(cz_fidelities[:, 0]))
print('min fidelity in CSV:', np.min(cz_fidelities[:, 0]))

# %%
# GRAPEcomp
fig, ax = plt.subplots()
plot_fidelity("../QutritSpeedLimitData/Fidelities/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="QuOpt", graph_type="CZ", ax=ax)
plot_fidelity("../QutritSpeedLimitData/NICT Data/QuditCZFidelity_3.csv", label="GRAPE", graph_type="CZ", ax=ax)
plt.tight_layout()
plt.savefig('./Revision_Plots/GRAPEcomp2.pdf')
plt.show()

# %%
# GRAPEcomp_CZ4
fig, ax = plt.subplots()
plot_fidelity("../QutritSpeedLimitData/Fidelities/quatrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="QuOpt", graph_type="CZ", ax=ax)
plot_fidelity("../QutritSpeedLimitData/NICT Data/QutritSpeedLimits_QutritCZ_3_5_0.csv", label="GRAPE", graph_type="CZ", ax=ax)
plt.tight_layout()
#plt.savefig('../../Previous Plots/GRAPEcomp_CZ4.pdf')
plt.show()

# %%
# Scan Data/Weights for qutrit capacitiveCoupling CZ weights and compute reconstruction fidelity
import glob
import numpy as np
import pandas as pd
import torch
from helperFuncs import genCouplMat, genDrive, genTwoQuditBasis, gateGen

level = 3
N = 2
maxDriveStrength = 40
tmin = np.pi / 4
gate_time = 1.0 * tmin

patterns = [
    "**/QutritSpeedLimitData/**/Weights*/Weights_t*.csv",
    "**/Optimal_Control/**/Weights*/Weights_t*.csv",
    "**/Optimal_Control/**/Weights/**/Weights_t*.csv",
]

weight_files = set()
for p in patterns:
    weight_files.update(glob.glob(p, recursive=True))
weight_files = sorted(list(weight_files))
print('Found', len(weight_files), 'weight files to check')

results = []
for path in weight_files:
    # Only interested in qutrit_CZ_capacitiveCoup files
    if 'qutrit_CZ_capacitiveCoup' not in path:
        continue
    try:
        weights = pd.read_csv(path, header=None).to_numpy()
        M = weights.shape[0]
        id_level = np.eye(level)
        drives = []
        for l in range(1, level):
            drives.append(genDrive(level, l, 'x'))
            drives.append(genDrive(level, l, 'y'))

        U = torch.eye(level ** N, dtype=torch.cdouble)
        for m in range(M):
            pulse_coef = torch.tensor(weights[m], dtype=torch.double)
            H1 = torch.zeros((level ** N, level ** N), dtype=torch.cdouble)
            for i, d in enumerate(drives):
                # time-independent pulses: no envelope
                pauli_temp = 1
                for j in range(N):
                    if j == i//2:
                        pauli_temp = np.kron(pauli_temp, d)
                    else:
                        pauli_temp = np.kron(pauli_temp, id_level)
                H1 = H1 + maxDriveStrength * torch.cos(pulse_coef[i % (len(drives))]) * torch.tensor(pauli_temp, dtype=torch.cdouble)
            H = torch.tensor(genCouplMat('capacitiveCoup', level), dtype=torch.cdouble) + H1
            U = torch.matmul(torch.matrix_exp(-1j * H * (gate_time / M)), U)

        input_gate = torch.tensor(gateGen('CZ', level), dtype=torch.cdouble)
        SU = genTwoQuditBasis(level, level, torch.cdouble)
        fid = 0
        for U_basis in SU:
            eps_U = torch.matmul(torch.matmul(U, U_basis), U.conj().T)
            target_U = torch.matmul(torch.matmul(input_gate, U_basis.conj().T), input_gate.conj().T)
            fid += torch.trace(torch.matmul(target_U, eps_U))
        d2 = level ** N
        fidelity = abs((fid + d2 ** 2) / ((d2 ** 2) * (d2 + 1)))
        results.append((path, float(fidelity)))
    except Exception as e:
        print('error', path, e)

# Report any high fidelity matches (>= 0.95)
high = [(p,f) for p,f in results if f >= 0.95]
print('High-fidelity count (>=0.95):', len(high))
for p,f in sorted(high, key=lambda x: x[1], reverse=True):
    print(f'{f:.10f}    {p}')

# Also print top 8 results
for p,f in sorted(results, key=lambda x: x[1], reverse=True)[:8]:
    print(f'{f:.10f}    {p}')

# %%
# qutritCZ — single QuOpt curve
plot_fidelity("./coupling_data/capacitiveCoup/Fidelities/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv",label="capactive coup")
plot_fidelity(
    "./Revision_Data/qutrit_CZ_capacitiveCoup_EC_M40_SGD_CFME4_g1.0_maxT2.0_maxD40_it5000.csv",
    graph_type="CZ",label="Excitation Conserving"
)
plt.savefig("./Revision_Plots/Excitation_Conserving.pdf")

# %%
from helperFuncs import *
printMat(genCouplMat("capacitiveCoup",3))
# Out:
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 1.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i,
#  1.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 2.00+0.00i,
#  0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 1.41+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,
#  0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 2.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i, 0.00+0.00i,

# %%
from helperFuncs import *
# CTL (crosstalk + leakage / ORT) qutrit CZ comparison: QuOpt vs GRAPE.
# QuOpt curve combines the M40/M50/M80/M120 sweeps (plot_fidelity's groupby-max
# picks the best available fidelity at each T across the overlapping files).
# GRAPE curve is DIGITIZED FROM THE FIGURE 8 IMAGE (no underlying data file was
# found) -- treat as an approximate visual read, not authoritative data.
fig, ax = plt.subplots()
plot_fidelity(
    "./CTL_CZ_Data/CTL/capacitiveCoup/Fidelities/qutrit_CZ_capacitiveCoup_CTL_combined_leakage14.0_maxD40_CTh0.002_stag17.0_it5000.csv",
    label="QuOpt", graph_type="CZ", ax=ax,
)
plot_fidelity(
    "./CTL_CZ_Data/Sahel_Data_Digitized/GRAPE_QutritCZ_ORT_Figure8_digitized_approx.csv",
    label="GRAPE", graph_type="CZ", ax=ax,
)
plt.savefig("./Revision_Plots/CTL_CZ_Comparison.pdf")
plt.tight_layout()
plt.show()

# %%
# Ququart (d=4) SWAP gate, closed system (no leakage)
fig, ax = plt.subplots()
plot_fidelity(
    f"./Ququart_SWAP_Data/Closed_System/Fidelities/quatrit_SWAP_closed_system.csv",
    label="QuOpt", graph_type="SWAP", ax=ax,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Log-Scale Infidelity: Qutrit CZ, QuOpt vs GRAPE
#
# Same two datasets as the `GRAPEcomp` cell above, plotted as $1-F$ on a log y-axis instead of $F$ on a linear one.

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_infidelity(
    csv_path: str,
    graph_type: str = "CNOT",
    label: str | None = None,
    ax: plt.Axes | None = None,
    save_path: str | None = None,
) -> plt.Axes:
    plt.rcParams["text.usetex"] = False
    plt.rcParams.update({
        "font.family": "serif",
        "mathtext.fontset": "cm",
    })
    df = pd.read_csv(csv_path, header=None, names=["F", "T_over_Tmin"])
    df = (
        df.groupby("T_over_Tmin", as_index=False)["F"]
        .max()
        .sort_values("T_over_Tmin")
    )
    # Below machine precision, 1-F is dominated by float64 rounding noise
    # (and can go negative). Forward-fill from the last trustworthy value
    # instead of dropping those points, so the line holds flat at the last
    # real infidelity rather than falling to an arbitrary floor.
    infidelity = (1 - df["F"]).where(lambda s: s > 0).ffill()
    if ax is None:
        ax = plt.gca()
    ax.plot(df["T_over_Tmin"], infidelity, marker="o", label=label)
    ax.set_yscale("log")
    ax.set_xlabel(r"$T/T_{min}^{ %s}$" % graph_type, fontsize=16)
    ax.set_ylabel(r"$1-F$", fontsize=16)
    ax.grid(True)
    handles, labels = ax.get_legend_handles_labels()
    if labels:
        ax.legend(fontsize=13, prop={"family": "serif"})
    if save_path:
        ax.get_figure().tight_layout()
        ax.get_figure().savefig(save_path)
    return ax

fig, ax = plt.subplots()
plot_infidelity("../QutritSpeedLimitData/Fidelities/qutrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="QuOpt", graph_type="CZ", ax=ax)
plot_infidelity("../QutritSpeedLimitData/NICT Data/QuditCZFidelity_3.csv", label="GRAPE", graph_type="CZ", ax=ax)
ax.set_ylim(bottom=1e-13)
plt.tight_layout()
plt.savefig('../../Previous Plots/GRAPEcomp_log.pdf')
plt.show()

# %%
# GRAPEcomp
fig, ax = plt.subplots()
plot_fidelity("./Revision_Data/SWAP_Data/quatrit_SWAP_capacitiveCoup_M40_SGD_CFME4_g1.0_maxT2.0_maxD40_it5000.csv", label="QuOpt", graph_type="SWAP", ax=ax)
plot_fidelity("./Revision_Data/SWAP_Data/QuditSWAPFidelity_4_FullOnePhotonControl.csv", label="GRAPE", graph_type="SWAP", ax=ax)
plt.tight_layout()
plt.savefig('./Revision_Plots/SWAP4.pdf')
plt.show()

# %% [markdown]
# ## Log-Scale Infidelity: Ququart CZ, QuOpt vs GRAPE
#
# Same two datasets as the `GRAPEcomp_CZ4` cell above, plotted as $1-F$ on a log y-axis.

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_infidelity(
    csv_path: str,
    graph_type: str = "CNOT",
    label: str | None = None,
    ax: plt.Axes | None = None,
    save_path: str | None = None,
) -> plt.Axes:
    plt.rcParams["text.usetex"] = False
    plt.rcParams.update({
        "font.family": "serif",
        "mathtext.fontset": "cm",
    })
    df = pd.read_csv(csv_path, header=None, names=["F", "T_over_Tmin"])
    df = (
        df.groupby("T_over_Tmin", as_index=False)["F"]
        .max()
        .sort_values("T_over_Tmin")
    )
    # Below machine precision, 1-F is dominated by float64 rounding noise
    # (and can go negative). Forward-fill from the last trustworthy value
    # instead of dropping those points, so the line holds flat at the last
    # real infidelity rather than falling to an arbitrary floor.
    infidelity = (1 - df["F"]).where(lambda s: s > 0).ffill()
    if ax is None:
        ax = plt.gca()
    ax.plot(df["T_over_Tmin"], infidelity, marker="o", label=label)
    ax.set_yscale("log")
    ax.set_xlabel(r"$T/T_{min}^{ %s}$" % graph_type, fontsize=16)
    ax.set_ylabel(r"$1-F$", fontsize=16)
    ax.grid(True)
    handles, labels = ax.get_legend_handles_labels()
    if labels:
        ax.legend(fontsize=13, prop={"family": "serif"})
    if save_path:
        ax.get_figure().tight_layout()
        ax.get_figure().savefig(save_path)
    return ax

fig, ax = plt.subplots()
plot_infidelity("../QutritSpeedLimitData/Fidelities/quatrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="QuOpt", graph_type="CZ", ax=ax)
plot_infidelity("./Revision_Data/Sahel_Data/QuditCZFidelity_4.csv", label="GRAPE", graph_type="CZ", ax=ax)
ax.set_ylim(bottom=1e-14)
plt.tight_layout()
plt.savefig('./Revision_Plots/GRAPEcomp_CZ4_log.pdf')
plt.show()

# %%
# GRAPEcomp_CZ4
fig, ax = plt.subplots()
plot_fidelity("../QutritSpeedLimitData/Fidelities/quatrit_CZ_capacitiveCoup_M40_SGD_SRK2_g1.0_maxT2.0_maxD40_it5000.csv", label="QuOpt", graph_type="CZ", ax=ax)
plot_fidelity("../QutritSpeedLimitData/NICT Data/QutritSpeedLimits_QutritCZ_3_5_0.csv", label="GRAPE", graph_type="CZ", ax=ax)
plt.tight_layout()
#plt.savefig('../../Previous Plots/GRAPEcomp_CZ4.pdf')
plt.show()

# %% [markdown]
# ## GRAPE_CZ4_ORT
#
# Recreation of `NICT_Paper.ipynb`'s `GRAPE_CZ4_ORT.pdf` cell. That notebook is dead on this machine (`from SumHelpFunc import *` and its `../../Sahel Data/`, `../../Paper2FinalData/` paths don't exist anywhere in the repo), so this rebuilds the same figure with the working `plot_fidelity` toolchain. Source data (`QuquartSpeedLimits_4_5_0.txt`, ququart CZ off-resonant-transition GRAPE sweep) has been relocated to `NICT Data/` and converted to the standard `F,T` CSV format. Standalone GRAPE curve, matching the original (no QuOpt comparison in that cell).

# %%
fig, ax = plt.subplots()
plot_fidelity(
    "../QutritSpeedLimitData/NICT Data/QuquartSpeedLimits_4_5_0.csv",
    label="GRAPE", graph_type="CZ", ax=ax
)
plot_fidelity(
    "../QutritSpeedLimitData/Fidelities/ququart_CTL_CZ_Data.csv",
    label="QuOpt", graph_type="CZ", ax=ax
)
plt.tight_layout()
plt.savefig("./Revision_Plots/CZ4_CTL.pdf")
plt.show()
